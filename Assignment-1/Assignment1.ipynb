# %%
# !pip install -q tensorflow

import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
wine = load_wine()

X = wine.data
y = wine.target

# %%
df = pd.DataFrame(X, columns=wine.feature_names)
df["Target"] = y

print("\nFirst Five Records:")
print(df.head())

print("\nDataset Shape:", df.shape)

print("\nDataset Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# First Five Records:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  Target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0
#
# Dataset Shape: (178, 14)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
#  12  proline                       178 non-null    float64
#  13  Target                        178 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 19.6 KB
# None
#
# Missing Values:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# Target                          0
# dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)
print("\nTraining Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (142, 13)
# Testing Data Shape: (36, 13)

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(13,)),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.9655 - val_loss: 0.0483
# Epoch 2/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9655 - val_loss: 0.0475
# Epoch 3/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.9655 - val_loss: 0.0465
# Epoch 4/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9655 - val_loss: 0.0455
# Epoch 5/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.9655 - val_loss: 0.0445
# Epoch 6/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0176 - val_accuracy: 0.9655 - val_loss: 0.0439
# Epoch 7/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.9655 - val_loss: 0.0435
# Epoch 8/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.9655 - val_loss: 0.0428
# Epoch 9/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0159 - val_accuracy: 0.9655 - val_loss: 0.0424
# Epoch 10/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.9655 - val_loss: 0.0431
# Epoch 11/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.9655 - val_loss: 0.0428
# Epoch 12/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.9655 - val_loss: 0.0419
# Epoch 13/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9655 - val_loss: 0.0405
# Epoch 14/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9655 - val_loss: 0.0391
# Epoch 15/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.9655 - val_loss: 0.0381
# Epoch 16/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9655 - val_loss: 0.0374
# Epoch 17/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9655 - val_loss: 0.0369
# Epoch 18/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9655 - val_loss: 0.0366
# Epoch 19/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9655 - val_loss: 0.0362
# Epoch 20/20
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9655 - val_loss: 0.0363

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("\nTest Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0211
#
# Test Loss: 0.021126074716448784
# Test Accuracy: 1.0
